# %%
import pandas as pd

file_path = r".\games_fully_vectorized.parquet"
df = pd.read_parquet(file_path)
# print(df.head(5))

devs = df.filter(like="developers_").columns
print(devs.shape)
pubs = df.filter(like="publishers_").columns
print(pubs.shape)
if devs.shape[0] == 1000 and pubs.shape[0] == 500:
    print('correct shape')
# Out:
# (1000,)
# (500,)
# correct shape
