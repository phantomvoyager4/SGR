# %%
import pandas as pd

# Target file path relative to current directory
file_path = r".\games_fully_vectorized.parquet"
df = pd.read_parquet(file_path)
print(df.head(50))
# Out:
#     is_free  price_overview  recommendations controller_support  \
# 0         0        0.000011         0.000000                  0
# 1         1        0.000000         0.000000                  0
# 2         1        0.000000         0.000000                  0
# 3         0        0.000016         0.000032                  0
# 4         0        0.000027         0.000000                  0
# 5         0        0.000008         0.000000                  0
# 6         0        0.000063         0.000042                  0
# 7         0        0.000076         0.000038                  0
# 8         0        0.000000         0.000000                  0
# 9         0        0.000034         0.000000                  0
# 10        0        0.000021         0.000000                  0
# 11        0        0.000030         0.000000                  0
# 12        0        0.000030         0.000000                  0
# 13        0        0.000030         0.000000                  0
# ...
